# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
print(train_images.shape)
print(len(train_labels))
print(train_labels)
print(test_images.shape)
print(len(test_labels))
test_labels
# Out:
# (60000, 28, 28)
# 60000
# [5 0 4 ... 5 6 8]
# (10000, 28, 28)
# 10000
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %%
from tensorflow import keras
from tensorflow.keras import layers
model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
    # softmax will return an array of 10 probability scores
])
model.compile(
    optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

model.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9240 - loss: 0.2660
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9689 - loss: 0.1075
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9786 - loss: 0.0715
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9846 - loss: 0.0516
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9881 - loss: 0.0388

# %%
#Making predictions

#takes the test_images 1-10
test_digits = test_images[0:10]
# tries to predict the output for each image
predictions = model.predict(test_digits)
predictions[0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# array([1.3347433e-07, 4.9952611e-09, 2.6922385e-06, 3.9826211e-04,
#        1.6339053e-11, 2.2437148e-07, 1.8754876e-11, 9.9959046e-01,
#        1.6534052e-07, 8.0992650e-06], dtype=float32)

# %%
print(predictions[0].argmax())
print(predictions[0][7])
# Out:
# 7
# 0.99959046

# %%
test_labels[0]
# Out:
# np.uint8(7)

# %%
#Evaluate model on new data
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"test_acc: {test_acc}")

#performing worse on new data compared to the training data is an example of over fitting
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9797 - loss: 0.0646
# test_acc: 0.9797000288963318
